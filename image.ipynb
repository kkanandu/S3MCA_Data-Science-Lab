# %%
import numpy as np
from scipy import ndimage
from PIL import Image
import matplotlib.pyplot as plt
img =Image.open(r"C:\Users\MCA09\Downloads\OIP.jpg") 
plt.imshow(img)
plt.title("Original Image")
plt.show()

# %%
#rotate 
flip = np.flipud(img)
plt.imshow(flip)
plt.title("rotate Image")
plt.show()

# %%
#rotate
rotate = ndimage.rotate(img,30)
plt.imshow(rotate)
plt.title("rotate Image 30")
plt.show()

# %%
#rotate simple method
a=np.array(img)
b=ndimage.rotate(a,120)
plt.title("rotate Image 120")
plt.imshow(b)

# %%
# a=np.array(img)
# b=ndimage.zoom(a(.5.4))
# plt.imshow(b)


#blur image
blur = ndimage.gaussian_filter(img,sigma=2)
plt.imshow(blur)
plt.title("blurred Image")
plt.show()

# %%
#rotate simple method
a=np.array(img)
b=ndimage.rotate(a,120)
plt.title("rotate Image 120")
plt.imshow(b)

# a=np.array(img)
# b=ndimage.zoom(a(.5.4))
# plt.imshow(b)

# %%
d=ndimage.zoom(a,(.5,.2,1))
plt.imshow(d)
plt.title("zoom Image")
# Out:
# Text(0.5, 1.0, 'zoom Image')
