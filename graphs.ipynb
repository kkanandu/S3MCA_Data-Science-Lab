# %%
#simple plot
import numpy as np
from matplotlib import pyplot as plt
x=[5,2,4,6]
y=[7,3,10,7]

plt.plot(x,marker='x')
plt.plot(y)
plt.legend(['first line','second line'])
plt.show()

# %%
#bar plot
x=['akash','anandu','shameer']
y=[7,4,10]
plt.bar(x,y,color='green')
plt.plot(y,color='red')
plt.xlabel("Names")
plt.ylabel("CGPA")
plt.title("cgpa of students")
plt.legend(['Names','CGPA'])

# %%
#histogram plot
x=np.random.rand(800)
plt.hist(x,bins=20,color='yellow')
plt.show()

# %%
#pie plot
x=[2,4,7]
y=[0.1,0,0]
plt.pie(x,explode=y)
plt.legend(['apple','orange','grape'])

# %%
x=[3,4,6,1]
y=[4,7,1,7]
plt.scatter(x,y,marker='*')

# %%
#sine
x=np.arange(0,20,0.1)
y=np.sin(x)
plt.plot(x,y)

# %%
#cosine
x=np.arange(0,20,0.1)
y=np.cos(x)
plt.plot(x,y)

# %%
a=np.arange(0,20,0.1)
b=np.cos(a)
c=np.arange(0,20,0.1 )
d=np.sin(c)
plt.subplot(1,1,1)
# plt.plot(a,b,c,d)
plt.plot(b,color='red')
plt.plot(d,color='blue')
